# %% [markdown]
# ## Яндекс Практикум, курс "Инженер Машинного Обучения" (2024 г.)
# ## Проект 4-го спринта: "Создание рекомендательной системы"

# %% [markdown]
# ## Этап 4. Сервис рекомендаций

# %% [markdown]
# __Постановка задачи__
#
# Напишите FastAPI-микросервис для выдачи рекомендаций, который:
# - принимает запрос с идентификатором пользователя и выдаёт рекомендации,
# - учитывает историю пользователя,
# - смешивает онлайн- и оффлайн-рекомендации.
#
# В README опишите стратегию смешивания онлайн- и оффлайн-рекомендаций.
#
# Выполните тестирование микросервиса в ноутбуке `part_3_test.ipynb`:
# - для пользователя без персональных рекомендаций,
# - для пользователя с персональными рекомендациями, но без онлайн-истории,
# - для пользователя с персональными рекомендациями и онлайн-историей.

# %% [markdown]
# ### Инициализация

# %%
import numpy as np
import pandas as pd
import requests

# %%
import sys

# Проверяем, в каком окружении работаем
print(sys.executable)
# Out:
# /home/mle-user/.venv/bin/python

# %%
# Адреса сервисов
recommendations_url = "http://127.0.0.1:8000"
features_store_url = "http://127.0.0.1:8010"
events_store_url = "http://127.0.0.1:8020"

# Общий заголовок для всех запросов
headers = {"Content-type": "application/json", "Accept": "text/plain"}

# %% [markdown]
# Для запуска сервисов с помощью uvicorn необходимо выполнить 3 команды в 3-х разных терминалах, находясь в папке проекта:
#
# ```
# uvicorn recommendations_service:app
# uvicorn events_service:app --port 8020
# uvicorn features_service:app --port 8010
# ```

# %% [markdown]
# ### Загрузка данных
#
# Загрузким треки для отображения рекомендаций со всеми полями, а также сами рекомендации, чтобы выбирать из них пользователей и объекты для тестирования

# %%
items = pd.read_parquet("items.parquet")
recommendations = pd.read_parquet('recommendations.parquet')
similar = pd.read_parquet('similar.parquet')

# %% [markdown]
# ### Получение рекомендаций по умолчанию
#
# Напишем вспомогательную функцию для отображения объектов по их идентификаторам

# %%
def display_items(item_ids):

    item_columns_to_use = ["item_id", "name", "genres", "albums", "artists"]
    
    items_selected = items.query("item_id in @item_ids")[item_columns_to_use]
    items_selected = items_selected.set_index("item_id").reindex(item_ids)
    items_selected = items_selected.reset_index()
    
    display(items_selected)

# %% [markdown]
# Отправляем запрос для получения рекомендаций по умолчанию, т.е. из числа топ-треков

# %%
params = {'k': 10}
resp = requests.post(recommendations_url + "/recommendations_default", headers=headers, params=params)
if resp.status_code == 200:
    resp = resp.json()
    display_items(resp['recs'])
else:
    print(f"status code: {resp.status_code}")
# Out:
#     item_id                      name                        genres  \
# 0     53404   Smells Like Teen Spirit  [alternative, allrock, rock]
# 1    178529                      Numb              [numetal, metal]
# 2     37384                    Zombie               [allrock, rock]
# 3   6705392         Seven Nation Army                 [alternative]
# 4  33311009                  Believer               [allrock, rock]
# 5    328683          Bring Me To Life  [alternative, allrock, rock]
# 6    148345           Californication               [allrock, rock]
# 7    795836         Shape Of My Heart          [allrock, pop, rock]
# 8    630670  You're Gonna Go Far, Kid                        [punk]
# 9    178495                In the End              [numetal, metal]
#
#                                               albums                  artists
# 0  [Smells Like Teen Spirit / In Bloom / On A Pla...                [Nirvana]
# 1                        [Meteora, 00s Rock Anthems]            [Linkin Park]
# 2  [90s Alternative, MNM Sing Your Song: Back To ...        [The Cranberries]
# 3  [Pay Close Attention : XL Recordings, Radio 1 ...      [The White Stripes]
# 4  [Horoscope Tunes: Cancer, Workout Music Hits 2...        [Imagine Dragons]
# 5  [Mental Health 2020, Monster Millennium Hits, ...            [Evanescence]
# 6  [The Studio Album Collection 1991-2011, Greate...  [Red Hot Chili Peppers]
# 7  [25 Years, Сентиментальные рок-песни, Ten Summ...                  [Sting]
# 8  [You're Gonna Go Far, Kid, Sleep Music Rock Ed...          [The Offspring]
# 9  [Antyradio: Najlepszy Rock Na Swiecie Vol. 4, ...            [Linkin Park]

# %% [markdown]
# ### Получение персональных рекомендаций без онлайн-истории

# %%
# Выберем произвольного пользователя случайным образом
user_id = recommendations['user_id'].sample().iat[0]
user_id
# Out:
# 12081

# %%
# Посмотрим, какие есть для него рекомендации
recommendations.query('user_id == @user_id')
# Out:
#    user_id  item_id  als_score  cnt_score  tracks_played_by_user     score  \
# 6    12081    73495   0.812035   0.927586                   2009  0.997894
#
#    rank
# 6     1

# %% [markdown]
# Сравним содержимое файла с результатом запроса

# %%
# Отправляем запрос для получения только оффлайн-рекомендаций
params = {'user_id': user_id, 'k': 10}
resp = requests.post(recommendations_url + "/recommendations_offline", headers=headers, params=params)
if resp.status_code == 200:
    resp = resp.json()
    display_items(resp['recs'])
else:
    recs = []
    print(f"status code: {resp.status_code}")
# Out:
#    item_id                         name                     genres  \
# 0    73495  Angels (Love Is The Answer)  [dance, electronics, pop]
#
#                                               albums    artists
# 0  [Valentine's Day 2022 - cele mai frumoase melo...  [Morandi]

# %% [markdown]
# ### Получение персональных рекомендаций с онлайн-историей

# %% [markdown]
# Выберем 3 произвольных трека, имеющих i2i-рекомендации, и добавим их в онлайн-историю пользователя

# %%
# Выбираем 3 объекта
item_ids = similar['item_id_1'].unique()[:3]
print(item_ids)

# Добавляем в онлайн-историю пользователя
for item_id in item_ids:
    params = {"user_id": user_id, "item_id": item_id}
    resp = requests.post(events_store_url + "/put", headers=headers, params=params)
    if resp.status_code == 200:
        resp = resp.json()
        print(resp['result'])    
    else:
        print(f"status code: {resp.status_code}")
# Out:
# [549 553 558]
# ok
# ok
# ok

# %% [markdown]
# Проверим, что события добавились, причем в обратном порядке

# %%
params = {"user_id": user_id, "k": 3}
resp = requests.post(events_store_url + "/get", headers=headers, params=params)
if resp.status_code == 200:
    resp = resp.json()
    print(resp['events'])    
else:
    print(f"status code: {resp.status_code}")
# Out:
# [558, 553, 549]

# %% [markdown]
# Протестируем работу сервиса `feautures_service`.
#
# Возмьмем последний объект из списка выше и найдем похожие на него треки из файла `similar.parquet`

# %%
item_id_1 = item_ids[-1]
similar.query('item_id_1 == @item_id_1')
# Out:
#        score  item_id_1  item_id_2
# 23  0.924216        558    1706463
# 24  0.908504        558    1706462
# 25  0.904736        558     550048
# 26  0.897181        558      69658
# 27  0.894441        558        553
# 28  0.886535        558      71239
# 29  0.885370        558    2277920
# 30  0.881694        558      71965
# 31  0.881250        558      34300
# 32  0.873259        558   10260869

# %% [markdown]
# Теперь получим тот же набор объектов с помощью сервиса `features_service`

# %%
params = {"item_id": item_id_1, "k": 10}
resp = requests.post(features_store_url +"/similar_items", headers=headers, params=params)
if resp.status_code == 200:
    resp = resp.json()
    print(resp['item_id_2'])    
else:
    print(f"status code: {resp.status_code}")
# Out:
# [1706463, 1706462, 550048, 69658, 553, 71239, 2277920, 71965, 34300, 10260869]

# %% [markdown]
# Протестируем запрос к сервису `reccomendations_service` для получения объектов, похожих на 3 последних трека из онлайн-истории данного пользователя

# %%
params = {'user_id': user_id, 'k': 10}
resp = requests.post(recommendations_url + "/recommendations_online", headers=headers, params=params)
if resp.status_code == 200:
    resp = resp.json()
    display_items(resp['recs'])
else:
    recs = []
    print(f"status code: {resp.status_code}")
# Out:
#      item_id                   name                   genres  \
# 0    1706462   The Time (Dirty Bit)       [electronics, pop]
# 1    1706463   Don’t Stop The Party       [electronics, pop]
# 2      26771          London Bridge                    [rnb]
# 3       4198           Fergalicious                    [rnb]
# 4      69658  I Got It From My Mama            [electronics]
# 5   37402640                Impacto        [latinfolk, folk]
# 6     631538          Boom Boom Pow                    [rnb]
# 7     123846           Lose Control        [rap, foreignrap]
# 8      12281               My Humps        [rap, foreignrap]
# 9      78710           Party People   [rap, rnb, foreignrap]
# 10       549                Imma Be       [electronics, pop]
# 11       553          Boom Boom Pow  [electronics, pop, rnb]
# 12    550048       Gettin' Over You                  [dance]
# 13    629590                Run It!                    [rnb]
# 14    630635              Kiss Kiss                    [rnb]
# 15       558         Rock That Body       [electronics, pop]
# 16     71239               Hey Mama                    [rnb]
# 17   2277920      Champagne Showers            [electronics]
# 18     71965                 Clumsy                    [rnb]
# 19     34300       The Sweet Escape                    [pop]
# 20  10260869              Bang Bang            [electronics]
# 21   2179872                  Sweat                  [dance]
#
#                                                albums  \
# 0   [Kids Songs: Game Day!, Party de Revelion 2021...
# 1   [The Beginning, NRJ 200% Hits 2011 Vol 2, The ...
# 2   [Faxina Pop, Летняя дискотека, Ready Steady Ib...
# 3   [Chicks With Kick, The Dutchess Deluxe, Pregam...
# 4   [Mom Songs, Hip Hop: The Collection 2008, Ulti...
# 5                           [El Cartel: The Big Boss]
# 6                             [Now 20, Boom Boom Pow]
# 7                        [Respect M.E., The Cookbook]
# 8   [Monkey Business, Junior Prom, Horoscope Tunes...
# 9   [The Dutchess Deluxe EP, Brass Knuckles, The D...
# 10  [Junior Prom, 2010s Gaming Music, Trending Sou...
# 11  [Junior Prom, Halloween Pop Party, Halftime Po...
# 12  [NRJ Hits 15, Jersey Shore Soundtrack, Gettin'...
# 13    [Run It!, Chris Brown / Exclusive, Chris Brown]
# 14  [Exclusive, Chris Brown / Exclusive, R&B Loves...
# 15  [Best of 00's - Anni Duemila, Throwback 00's, ...
# 16  [Best of 00's - Anni Duemila, Mother's Day Pla...
# 17  [New Years Eve 2022, Sorry For Party Rocking, ...
# 18                                           [Clumsy]
# 19  [Summer Mix 2020, 2000's POP, Party All Night,...
# 20  [Aerobics music 2020, Going Viral, Now Dance 3...
# 21  [EDM Hits 2000 Vol. 1, Festival Bangers, Sweat...
#
#                                               artists
# 0                                   [Black Eyed Peas]
# 1                                   [Black Eyed Peas]
# 2                                            [Fergie]
# 3                                 [will.i.am, Fergie]
# 4                                         [will.i.am]
# 5                              [Daddy Yankee, Fergie]
# 6                                   [Black Eyed Peas]
# 7               [Ciara, Fatman Scoop, Missy  Elliott]
# 8                                   [Black Eyed Peas]
# 9                                     [Nelly, Fergie]
# 10                                  [Black Eyed Peas]
# 11                                  [Black Eyed Peas]
# 12        [Fergie, David Guetta, Chris Willis, LMFAO]
# 13                       [Juelz Santana, Chris Brown]
# 14                              [T-Pain, Chris Brown]
# 15                                  [Black Eyed Peas]
# 16                                  [Black Eyed Peas]
# 17                             [Natalia Kills, LMFAO]
# 18                                           [Fergie]
# 19                               [Gwen Stefani, Akon]
# 20                                        [will.i.am]
# 21  [Snoop Dogg, Giorgio Tuinfort, David Guetta, F...

# %% [markdown]
# Наконец, получим смешанные рекомендации. На нечетных местах будут оффлайн-рекомендации, на четных - онлайн.

# %%
params = {"user_id": user_id, 'k': 10}
resp = requests.post(recommendations_url + "/recommendations", headers=headers, params=params)
if resp.status_code == 200:
    resp = resp.json()
    display_items(resp['recs'])
else:
    print(f"status code: {resp.status_code}")
# Out:
#     item_id                         name                     genres  \
# 0     73495  Angels (Love Is The Answer)  [dance, electronics, pop]
# 1   1706462         The Time (Dirty Bit)         [electronics, pop]
# 2   1706463         Don’t Stop The Party         [electronics, pop]
# 3     26771                London Bridge                      [rnb]
# 4      4198                 Fergalicious                      [rnb]
# 5     69658        I Got It From My Mama              [electronics]
# 6  37402640                      Impacto          [latinfolk, folk]
# 7    631538                Boom Boom Pow                      [rnb]
# 8    123846                 Lose Control          [rap, foreignrap]
# 9     12281                     My Humps          [rap, foreignrap]
#
#                                               albums  \
# 0  [Valentine's Day 2022 - cele mai frumoase melo...
# 1  [Kids Songs: Game Day!, Party de Revelion 2021...
# 2  [The Beginning, NRJ 200% Hits 2011 Vol 2, The ...
# 3  [Faxina Pop, Летняя дискотека, Ready Steady Ib...
# 4  [Chicks With Kick, The Dutchess Deluxe, Pregam...
# 5  [Mom Songs, Hip Hop: The Collection 2008, Ulti...
# 6                          [El Cartel: The Big Boss]
# 7                            [Now 20, Boom Boom Pow]
# 8                       [Respect M.E., The Cookbook]
# 9  [Monkey Business, Junior Prom, Horoscope Tunes...
#
#                                  artists
# 0                              [Morandi]
# 1                      [Black Eyed Peas]
# 2                      [Black Eyed Peas]
# 3                               [Fergie]
# 4                    [will.i.am, Fergie]
# 5                            [will.i.am]
# 6                 [Daddy Yankee, Fergie]
# 7                      [Black Eyed Peas]
# 8  [Ciara, Fatman Scoop, Missy  Elliott]
# 9                      [Black Eyed Peas]
