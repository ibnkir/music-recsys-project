# %% [markdown]
# ## Яндекс Практикум, курс "Инженер Машинного Обучения" (2024 г.)
# ## Проект 4-го спринта: "Создание рекомендательной системы"
# ***

# %% [markdown]
# ## Тестирование сервисов

# %% [markdown]
# __Постановка задачи__
#
# Напишите FastAPI-микросервис для выдачи рекомендаций, который:
# - принимает запрос с идентификатором пользователя и выдаёт рекомендации,
# - учитывает историю пользователя,
# - смешивает онлайн- и оффлайн-рекомендации.
#
# В README опишите стратегию смешивания оффлайн- и онлайн-рекомендаций.
#
# Оформите тестирование микросервиса в скрипте `test_service.py`
# - для пользователя без персональных рекомендаций,
# - для пользователя с персональными рекомендациями, но без онлайн-истории,
# - для пользователя с персональными рекомендациями и онлайн-историей.
#
# Выполните скрипт `test_service.py` для тестирования микросервиса, сохраните его вывод в файле `test_service.log`

# %% [markdown]
# ### Инициализация

# %%
import numpy as np
import pandas as pd
import requests

# %% [markdown]
# Задаем url-адреса трех веб-сервисов

# %%
# Основной сервис для получения оффлайн- и онлайн-рекомендаций
recommendations_url = "http://127.0.0.1:8000"

# Вспомогательный сервис для получения рекомендаций по умолчанию на основе топ-треков
features_store_url = "http://127.0.0.1:8010"

# Вспомогательный сервис для хранения и получения последних онлайн-событий пользователя
events_store_url = "http://127.0.0.1:8020"

# %%
# Общий заголовок для всех http-запросов
headers = {"Content-type": "application/json", "Accept": "text/plain"}

# %% [markdown]
# Чтобы запустить тестируемые сервисы, нужно выполнить 4 команды (по одному на каждый сервис) в 4-х разных терминалах, находясь в папке проекта:
# ```
# uvicorn recommendations_service:app
# uvicorn events_service:app --port 8020
# uvicorn features_service:app --port 8010
# uvicorn test_service:app --port 8030
# ```

# %% [markdown]
# ### Загрузка данных
#
# Загрузким треки для отображения рекомендаций со всеми полями, а также сами рекомендации, чтобы выбирать из них пользователей и объекты для тестирования

# %%
items = pd.read_parquet("items.parquet")
recommendations = pd.read_parquet('recommendations.parquet')
similar = pd.read_parquet('similar.parquet')
top_popular = pd.read_parquet('top_popular.parquet')

# %% [markdown]
# ### Получение рекомендаций по умолчанию
#
# В этом сценарии мы получаем рекомендации на основе топ-треков, когда у пользователя нет истории и соответственно нет персональных оффлайн-рекомендаций.
#
# Напишем вспомогательную функцию для отображения объектов по их идентификаторам

# %%
def display_items(item_ids):

    item_columns_to_use = ["item_id", "name", "genres", "albums", "artists"]
    
    items_selected = items.query("item_id in @item_ids")[item_columns_to_use]
    items_selected = items_selected.set_index("item_id").reindex(item_ids)
    items_selected = items_selected.reset_index()
    
    display(items_selected)

# %% [markdown]
# Посмотрим топ-рекомендации из соответствующего файла

# %%
top_popular.head(10)
# Out:
#    rank   item_id  plays  users                     name  \
# 0     1     53404  40905  40905  Smells Like Teen Spirit
# 1     2    178529  35411  35411                     Numb
# 2     3  33311009  34005  34005                 Believer
# 3     4  35505245  32259  32259               I Got Love
# 4     5     37384  30390  30390                   Zombie
# 5     6  24692821  28508  28508           Way Down We Go
# 6     7    795836  28285  28285        Shape Of My Heart
# 7     8   6705392  26781  26781        Seven Nation Army
# 8     9  32947997  26688  26688             Shape of You
# 9    10  45499814  26299  26299                     Life
#
#                          genres                         artists  \
# 0  [allrock, alternative, rock]                       [Nirvana]
# 1              [numetal, metal]                   [Linkin Park]
# 2               [allrock, rock]               [Imagine Dragons]
# 3                 [rusrap, rap]  [Miyagi & Эндшпиль, Рем Дигга]
# 4               [allrock, rock]               [The Cranberries]
# 5                       [indie]                         [KALEO]
# 6          [allrock, pop, rock]                         [Sting]
# 7                 [alternative]             [The White Stripes]
# 8                         [pop]                    [Ed Sheeran]
# 9                 [ruspop, pop]                        [Zivert]
#
#                                               albums
# 0  [Skiing Music, Nirvana, Nevermind, Smells Like...
# 1                        [Meteora, 00s Rock Anthems]
# 2  [Summertime Love, Family Friendly Summer Hits,...
# 3                                       [I Got Love]
# 4  [***** ***, Gold, MNM Sing Your Song: Back To ...
# 5  [DFM Dance 8, Hits and Stars 2018, Chilled Aco...
# 6  [Ten Summoner's Tales, 25 Years, Сентиментальн...
# 7  [Seven Nation Army, Radio 1 Sonar 1000, Pay Cl...
# 8               [Pop, Summer Vibes, ÷, Shape of You]
# 9  [Vinyl #1, Made in Russia, Vinyl #1. Deluxe Ve...

# %% [markdown]
# Отправим запрос для получения рекомендаций по умолчанию и сравним его резульат с данными выше

# %%
params = {'k': 10}
resp = requests.post(recommendations_url + "/recommendations_default", headers=headers, params=params)
if resp.status_code == 200:
    resp = resp.json()
    display_items(resp['recs'])
else:
    print(f"status code: {resp.status_code}")
# Out:
#     item_id                     name                        genres  \
# 0     53404  Smells Like Teen Spirit  [allrock, alternative, rock]
# 1    178529                     Numb              [numetal, metal]
# 2  33311009                 Believer               [allrock, rock]
# 3  35505245               I Got Love                 [rusrap, rap]
# 4     37384                   Zombie               [allrock, rock]
# 5  24692821           Way Down We Go                       [indie]
# 6    795836        Shape Of My Heart          [allrock, pop, rock]
# 7   6705392        Seven Nation Army                 [alternative]
# 8  32947997             Shape of You                         [pop]
# 9  45499814                     Life                 [ruspop, pop]
#
#                                               albums  \
# 0  [Skiing Music, Nirvana, Nevermind, Smells Like...
# 1                        [Meteora, 00s Rock Anthems]
# 2  [Summertime Love, Family Friendly Summer Hits,...
# 3                                       [I Got Love]
# 4  [***** ***, Gold, MNM Sing Your Song: Back To ...
# 5  [DFM Dance 8, Hits and Stars 2018, Chilled Aco...
# 6  [Ten Summoner's Tales, 25 Years, Сентиментальн...
# 7  [Seven Nation Army, Radio 1 Sonar 1000, Pay Cl...
# 8               [Pop, Summer Vibes, ÷, Shape of You]
# 9  [Vinyl #1, Made in Russia, Vinyl #1. Deluxe Ve...
#
#                           artists
# 0                       [Nirvana]
# 1                   [Linkin Park]
# 2               [Imagine Dragons]
# 3  [Miyagi & Эндшпиль, Рем Дигга]
# 4               [The Cranberries]
# 5                         [KALEO]
# 6                         [Sting]
# 7             [The White Stripes]
# 8                    [Ed Sheeran]
# 9                        [Zivert]

# %% [markdown]
# Результаты запроса и данные в файле совпадают.

# %% [markdown]
# ### Получение персональных рекомендаций без онлайн-истории
#
# В этом сценарии рекомендации извлекаются по идентификтору пользователя из данных, сгенерированных на основании истории пользователя.

# %%
# Выберем случайного пользователя из оффлайн-рекомендаций
user_id = recommendations['user_id'].sample().iat[0]
print(f"user_id выбранного пользователя: {user_id}")
# Out:
# user_id выбранного пользователя: 617032

# %%
# Посмотрим, какие для него есть рекомендации
recommendations.query('user_id == @user_id').head(10)
# Out:
#           user_id   item_id  als_score  tracks_played_by_user  genre_0  \
# 30810700   617032  32947997   1.012401                   63.0  0.37619
# 30810701   617032  29544272   0.837257                   63.0  0.37619
# 30810702   617032  18385776   0.456379                   63.0  0.37619
# 30810703   617032  34976783   0.268101                   63.0  0.37619
# 30810704   617032  26918469   0.196452                   63.0  0.37619
# 30810705   617032  31219146   0.193369                   63.0  0.37619
# 30810706   617032  31746480   0.191059                   63.0  0.37619
# 30810707   617032  24663745   0.179783                   63.0  0.37619
# 30810708   617032  30049955   0.177514                   63.0  0.37619
# 30810709   617032  21497837   0.174815                   63.0  0.37619
#
#           genre_20  genre_2  genre_11  genre_6  genre_74  genre_21  genre_4  \
# 30810700  0.050794      0.0  0.092593      0.0  0.015873  0.034921      0.0
# 30810701  0.050794      0.0  0.092593      0.0  0.015873  0.034921      0.0
# 30810702  0.050794      0.0  0.092593      0.0  0.015873  0.034921      0.0
# 30810703  0.050794      0.0  0.092593      0.0  0.015873  0.034921      0.0
# 30810704  0.050794      0.0  0.092593      0.0  0.015873  0.034921      0.0
# 30810705  0.050794      0.0  0.092593      0.0  0.015873  0.034921      0.0
# 30810706  0.050794      0.0  0.092593      0.0  0.015873  0.034921      0.0
# 30810707  0.050794      0.0  0.092593      0.0  0.015873  0.034921      0.0
# 30810708  0.050794      0.0  0.092593      0.0  0.015873  0.034921      0.0
# 30810709  0.050794      0.0  0.092593      0.0  0.015873  0.034921      0.0
#
#           genre_14  genre_10  genre_others     score  rank
# 30810700  0.164021  0.007937      0.257672  0.999968     1
# 30810701  0.164021  0.007937      0.257672  0.994152     2
# 30810702  0.164021  0.007937      0.257672  0.834461     3
# 30810703  0.164021  0.007937      0.257672  0.374376     4
# 30810704  0.164021  0.007937      0.257672  0.246755     5
# 30810705  0.164021  0.007937      0.257672  0.235464     6
# 30810706  0.164021  0.007937      0.257672  0.235464     7
# 30810707  0.164021  0.007937      0.257672  0.214850     8
# 30810708  0.164021  0.007937      0.257672  0.214850     9
# 30810709  0.164021  0.007937      0.257672  0.214850    10

# %% [markdown]
# Выполним запрос и сравним его результат с данными выше

# %%
# Отправляем запрос для получения только оффлайн-рекомендаций
params = {'user_id': user_id, 'k': 10}
resp = requests.post(recommendations_url + "/recommendations_offline", headers=headers, params=params)
if resp.status_code == 200:
    resp = resp.json()
    display_items(resp['recs'])
else:
    recs = []
    print(f"status code: {resp.status_code}")
# Out:
#     item_id                   name                       genres  \
# 0  32947997           Shape of You                        [pop]
# 1  29544272                  Human          [indie, soundtrack]
# 2  18385776                 Freaks  [house, dance, electronics]
# 3  34976783                Thunder              [allrock, rock]
# 4  26918469  We Don't Talk Anymore                        [pop]
# 5  31219146                 My Way                      [dance]
# 6  31746480               Rockabye                 [pop, dance]
# 7  24663745            Ocean Drive         [dance, electronics]
# 8  30049955            Lost on You                 [pop, dance]
# 9  21497837               Worth It                        [pop]
#
#                                               albums  \
# 0               [Pop, Summer Vibes, ÷, Shape of You]
# 1  [Some Chillout Music, Music Made for Chillout,...
# 2  [Танцевальный рай: Hit Mix, Wild Nights 2018, ...
# 3  [Spring Breakers 2021, Clean Kids Party Mix, K...
# 4               [Nine Track Mind, Autumn Music 2016]
# 5  [Летний Хит FM, My Way, I Love Skiing, ADM: Ac...
# 6  [DFM Dance 8, Pop Classics, Spring Music 2017,...
# 7  [Best Of The 10's: Dance, Pop Motivation, Work...
# 8  [NOW! That's What I Call Music, Радио и интерн...
# 9  [How To Be Single, Keep Calm & Party, Party Mi...
#
#                                  artists
# 0                           [Ed Sheeran]
# 1                       [Rag'n'Bone Man]
# 2                [Savage, Timmy Trumpet]
# 3                      [Imagine Dragons]
# 4           [Selena Gomez, Charlie Puth]
# 5                        [Calvin Harris]
# 6  [Clean Bandit, Anne-Marie, Sean Paul]
# 7                          [Duke Dumont]
# 8                                   [LP]
# 9               [Kid Ink, Fifth Harmony]

# %% [markdown]
# По `item_id` видим, что результаты запроса и данные в файле совпадают.

# %% [markdown]
# ### Получение персональных рекомендаций с онлайн-историей
#
# В этом сценарии к оффлайн-рекомендациям из предыдущего раздела добавляются объекты, похожие на 3 последних прослушанных трека из онлайн-истории.
#
# Возьмем 3 произвольных трека из i2i-рекомендаций и добавим их в онлайн-историю того же пользователя, что и в предыдущем тестовом сценарии

# %%
# Выбираем 3 объекта из i2i-рекомендаций
item_ids = similar['item_id_1'].unique()[:3]
print(item_ids)

# Добавляем их в онлайн-историю пользователя
for item_id in item_ids:
    params = {"user_id": user_id, "item_id": item_id}
    resp = requests.post(events_store_url + "/put", headers=headers, params=params)
    if resp.status_code == 200:
        resp = resp.json()
        print(resp['result'])    
    else:
        print(f"status code: {resp.status_code}")
# Out:
# [ 99262 590303 597196]
# ok
# ok
# ok

# %% [markdown]
# Проверим, что события добавились, причем в обратном порядке

# %%
params = {"user_id": user_id, "k": 3}
resp = requests.post(events_store_url + "/get", headers=headers, params=params)
if resp.status_code == 200:
    resp = resp.json()
    print(resp['events'])    
else:
    print(f"status code: {resp.status_code}")
# Out:
# [597196, 590303, 99262]

# %% [markdown]
# Протестируем работу сервиса `feautures_service`.
#
# Возмьмем последний объект из списка выше и найдем похожие на него треки из файла `similar.parquet`

# %%
item_id_1 = item_ids[-1]
similar.query('item_id_1 == @item_id_1').head(10)
# Out:
#        score  item_id_1  item_id_2
# 23  0.953137     597196   21101461
# 24  0.945990     597196   21101463
# 25  0.923976     597196     597227
# 26  0.921177     597196    2222537
# 27  0.911217     597196   24143071
# 28  0.909582     597196   38788303
# 29  0.908665     597196   21101459
# 30  0.906829     597196   27323612
# 31  0.905836     597196    2836249
# 32  0.904213     597196     597201

# %% [markdown]
# Теперь получим тот же набор объектов с помощью сервиса `features_service`

# %%
params = {"item_id": item_id_1, "k": 10}
resp = requests.post(features_store_url +"/similar_items", headers=headers, params=params)
if resp.status_code == 200:
    resp = resp.json()
    print(resp['item_id_2'])    
else:
    print(f"status code: {resp.status_code}")
# Out:
# [21101461, 21101463, 597227, 2222537, 24143071, 38788303, 21101459, 27323612, 2836249, 597201]

# %% [markdown]
# Видим, что данные совпадают.
#
# Протестируем запрос для получения объектов, похожих на 3 последних трека из онлайн-истории выбранного пользователя

# %%
params = {'user_id': user_id, 'k': 10}
resp = requests.post(recommendations_url + "/recommendations_online", headers=headers, params=params)
if resp.status_code == 200:
    resp = resp.json()
    display_items(resp['recs'])
else:
    recs = []
    print(f"status code: {resp.status_code}")
# Out:
#      item_id                          name                 genres  \
# 0     590413        В Багдаде всё спокойно          [ruspop, pop]
# 1   21101461                     Ды-ды-дым          [rusrap, rap]
# 2     590668                   Чио-Чио-сан          [ruspop, pop]
# 3     590164                         Париж          [ruspop, pop]
# 4   21101463                 Сочиняй мечты          [rusrap, rap]
# 5     590262                   Бомбей буги          [ruspop, pop]
# 6     590692            Великий инквизитор          [ruspop, pop]
# 7     591001                   Багама-Мама          [ruspop, pop]
# 8      99245                  Ragga Steady                  [pop]
# 9     590326  Девушка с Карибских островов          [ruspop, pop]
# 10  18117988                  Happy Nation                  [pop]
# 11    597227                    Вокруг шум          [rusrap, rap]
# 12  20909909                   Бомбей буги          [ruspop, pop]
# 13   2222537                         Метла          [rusrap, rap]
# 14    590865               Лондон, гуд бай          [ruspop, pop]
# 15     99241              Culture of Youth                  [pop]
# 16  24143071                        Решено          [rusrap, rap]
# 17  38788303         Легко ли быть молодым          [rusrap, rap]
# 18  21101459                    Вокруг шум          [rusrap, rap]
# 19  27323612                   Город дорог          [rusrap, rap]
# 20   2836249                  Шевели задом          [rusrap, rap]
# 21   4637878                       No Coke                  [pop]
# 22    597201                     Ды-ды-дым          [rusrap, rap]
# 23     99254               Poppadink Tribe                  [pop]
# 24  40667264                          Sexy                  [pop]
# 25    641551           No Limit (Extended)  [techno, electronics]
# 26  28132351                      No Limit                  [pop]
# 27   5462791            All That She Wants                  [pop]
# 28   2564599            All That She Wants                  [pop]
# 29   2470796              Living in Danger                  [pop]
#
#                                                albums              artists
# 0                               [Car-Mania, «Физрук»]            [Кар-Мэн]
# 1                                      [Лучшие песни]              [Каста]
# 2                                      [Вокруг света]            [Кар-Мэн]
# 3                                      [Вокруг света]            [Кар-Мэн]
# 4                                      [Лучшие песни]              [Каста]
# 5                               [Car-Mania, «Физрук»]            [Кар-Мэн]
# 6   [Русская массированная звуковая агрессия, «Физ...            [Кар-Мэн]
# 7                                      [Вокруг света]            [Кар-Мэн]
# 8                                 [Midi, Maxi & Efti]  [Midi, Maxi & Efti]
# 9                                         [Car-Mania]            [Кар-Мэн]
# 10                                     [Happy Nation]        [Ace of Base]
# 11                                     [Быль в глаза]              [Каста]
# 12                                       [Ультразвук]            [Кар-Мэн]
# 13                                               [ХЗ]              [Каста]
# 14                                     [Вокруг света]            [Кар-Мэн]
# 15                                [Midi, Maxi & Efti]  [Midi, Maxi & Efti]
# 16                                           [Решено]              [Каста]
# 17                                     [Эфир в норме]              [CENTR]
# 18                                     [Лучшие песни]              [Каста]
# 19                                           [Качели]       [Баста, CENTR]
# 20                                     [Американщина]           [Карандаш]
# 21                         [Hello Afrika (The Album)]          [Dr. Alban]
# 22                                     [Быль в глаза]              [Каста]
# 23                                [Midi, Maxi & Efti]  [Midi, Maxi & Efti]
# 24                               [Sexy, Belle Epoque]      [French Affair]
# 25                                         [No Limit]        [2 Unlimited]
# 26               [Дискотека 80-х и 90-х, Disco 80/90]        [2 Unlimited]
# 27                               [All That She Wants]        [Ace of Base]
# 28                                     [Happy Nation]        [Ace of Base]
# 29  [Living in Danger, Singles Of The 90s, Greates...        [Ace of Base]

# %% [markdown]
# Видим, что результат содержит в т.ч. объекты, похожие на последий трек из онлайн-истории пользователя.
#
# Наконец, получим смешанные рекомендации. На нечетных местах будут оффлайн-рекомендации, на четных - онлайн.

# %%
params = {"user_id": user_id, 'k': 10}
resp = requests.post(recommendations_url + "/recommendations", headers=headers, params=params)
if resp.status_code == 200:
    resp = resp.json()
    display_items(resp['recs'])
else:
    print(f"status code: {resp.status_code}")
# Out:
#     item_id                    name                       genres  \
# 0  32947997            Shape of You                        [pop]
# 1    590413  В Багдаде всё спокойно                [ruspop, pop]
# 2  29544272                   Human          [indie, soundtrack]
# 3  21101461               Ды-ды-дым                [rusrap, rap]
# 4  18385776                  Freaks  [house, dance, electronics]
# 5    590668             Чио-Чио-сан                [ruspop, pop]
# 6  34976783                 Thunder              [allrock, rock]
# 7    590164                   Париж                [ruspop, pop]
# 8  26918469   We Don't Talk Anymore                        [pop]
# 9  21101463           Сочиняй мечты                [rusrap, rap]
#
#                                               albums  \
# 0               [Pop, Summer Vibes, ÷, Shape of You]
# 1                              [Car-Mania, «Физрук»]
# 2  [Some Chillout Music, Music Made for Chillout,...
# 3                                     [Лучшие песни]
# 4  [Танцевальный рай: Hit Mix, Wild Nights 2018, ...
# 5                                     [Вокруг света]
# 6  [Spring Breakers 2021, Clean Kids Party Mix, K...
# 7                                     [Вокруг света]
# 8               [Nine Track Mind, Autumn Music 2016]
# 9                                     [Лучшие песни]
#
#                         artists
# 0                  [Ed Sheeran]
# 1                     [Кар-Мэн]
# 2              [Rag'n'Bone Man]
# 3                       [Каста]
# 4       [Savage, Timmy Trumpet]
# 5                     [Кар-Мэн]
# 6             [Imagine Dragons]
# 7                     [Кар-Мэн]
# 8  [Selena Gomez, Charlie Puth]
# 9                       [Каста]
